# %%
import requests
standings_url = "https://fbref.com/en/comps/82/Indian-Super-League-Stats"
data = requests.get(standings_url)
from bs4 import BeautifulSoup
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]
data = requests.get(team_urls[0])
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result  GF  GA  \
# 0  2022-10-09  19:30  Super League  Matchweek 1  Sun  Away      D   3   3
# 1  2022-10-15  19:30  Super League  Matchweek 2  Sat  Home      W   2   0
# 2  2022-10-22  17:30  Super League  Matchweek 3  Sat  Home      D   1   1
# 3  2022-10-28  19:30  Super League  Matchweek 4  Fri  Away      W   2   0
# 4  2022-11-06  19:30  Super League  Matchweek 5  Sun  Home      D   2   2
#
#           Opponent  Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist  PK  PKatt  \
# 0     Hyderabad FC    2  15    5  33.3  0.13   0.40   NaN   0      0
# 1           Odisha    1   7    3  42.9  0.14   0.33   NaN   0      0
# 2       Jamshedpur    1  14    5  35.7  0.07   0.20   NaN   0      0
# 3  Kerala Blasters    2  16    4  25.0  0.13   0.50   NaN   0      0
# 4      Mohun Bagan    2  21    7  33.3  0.10   0.29   NaN   0      0
#
#    Match Report
# 0  Match Report
# 1  Match Report
# 2  Match Report
# 3  Match Report
# 4  Match Report

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 0  2022-10-09  19:30  Super League  Matchweek 1  Sun  Away      D  3.0  3.0
# 1  2022-10-15  19:30  Super League  Matchweek 2  Sat  Home      W  2.0  0.0
# 2  2022-10-22  17:30  Super League  Matchweek 3  Sat  Home      D  1.0  1.0
# 3  2022-10-28  19:30  Super League  Matchweek 4  Fri  Away      W  2.0  0.0
# 4  2022-11-06  19:30  Super League  Matchweek 5  Sun  Home      D  2.0  2.0
#
#           Opponent  ...        Captain  Formation             Referee  \
# 0     Hyderabad FC  ...  Mourtada Fall      4-3-3     Tejas Nagvenkar
# 1           Odisha  ...    Rahul Bheke      4-3-3    Pranjal Banerjee
# 2       Jamshedpur  ...    Rahul Bheke      4-3-3        R. Venkatesh
# 3  Kerala Blasters  ...    Rahul Bheke    4-2-3-1  Aditya Purkayastha
# 4      Mohun Bagan  ...    Rahul Bheke      4-3-3     Rowan Arumughan
#
#    Match Report Notes  Sh  SoT  Dist  PK  PKatt
# 0  Match Report   NaN  15    5   NaN   0      0
# 1  Match Report   NaN   7    3   NaN   0      0
# 2  Match Report   NaN  14    5   NaN   0      0
# 3  Match Report   NaN  16    4   NaN   0      0
# 4  Match Report   NaN  21    7   NaN   0      0
#
# [5 rows x 22 columns]

# %%
team_data.shape
# Out:
# (19, 22)

# %%
team_data
# Out:
#           Date   Time          Comp         Round  Day Venue Result   GF   GA  \
# 0   2022-10-09  19:30  Super League   Matchweek 1  Sun  Away      D  3.0  3.0
# 1   2022-10-15  19:30  Super League   Matchweek 2  Sat  Home      W  2.0  0.0
# 2   2022-10-22  17:30  Super League   Matchweek 3  Sat  Home      D  1.0  1.0
# 3   2022-10-28  19:30  Super League   Matchweek 4  Fri  Away      W  2.0  0.0
# 4   2022-11-06  19:30  Super League   Matchweek 5  Sun  Home      D  2.0  2.0
# 5   2022-11-12  19:30  Super League   Matchweek 6  Sat  Away      W  6.0  2.0
# 6   2022-11-17  19:30  Super League   Matchweek 7  Thu  Home      W  4.0  0.0
# 7   2022-11-25  19:30  Super League   Matchweek 8  Fri  Away      W  3.0  1.0
# 8   2022-12-01  19:30  Super League   Matchweek 9  Thu  Home      W  4.0  1.0
# 9   2022-12-16  19:30  Super League  Matchweek 11  Fri  Away      W  3.0  0.0
# 10  2022-12-24  17:30  Super League  Matchweek 12  Sat  Home      W  2.0  1.0
# 11  2023-01-02  19:30  Super League  Matchweek 13  Mon  Away      W  4.0  2.0
# 12  2023-01-08  19:30  Super League  Matchweek 14  Sun  Home      W  4.0  0.0
# 13  2023-01-14  19:30  Super League  Matchweek 15  Sat  Away      W  1.0  0.0
# 14  2023-01-19  19:30  Super League  Matchweek 16  Thu  Home      W  4.0  0.0
# 15  2023-01-27  19:30  Super League  Matchweek 17  Fri  Away      W  2.0  1.0
# 16  2023-02-04  17:30  Super League  Matchweek 18  Sat  Home      D  1.0  1.0
# 17  2023-02-11  17:30  Super League  Matchweek 20  Sat  Away      W  5.0  3.0
# 18  2023-02-15  19:30  Super League  Matchweek 20  Wed  Away      L  1.0  2.0
#
#            Opponent  ...        Captain  Formation             Referee  \
# 0      Hyderabad FC  ...  Mourtada Fall      4-3-3     Tejas Nagvenkar
# 1            Odisha  ...    Rahul Bheke      4-3-3    Pranjal Banerjee
# 2        Jamshedpur  ...    Rahul Bheke      4-3-3        R. Venkatesh
# 3   Kerala Blasters  ...    Rahul Bheke    4-2-3-1  Aditya Purkayastha
# 4       Mohun Bagan  ...    Rahul Bheke      4-3-3     Rowan Arumughan
# 5        Chennaiyin  ...    Rahul Bheke      4-3-3     Ashwin Mohanlal
# 6         Bengaluru  ...    Rahul Bheke      4-3-3    C. R. Srikrishna
# 7     NorthEast Utd  ...    Rahul Bheke      4-3-3   S. Senthil Nathan
# 8               Goa  ...    Rahul Bheke      4-3-3       Pratik Mondal
# 9       East Bengal  ...  Mourtada Fall      4-3-3     Tejas Nagvenkar
# 10       Chennaiyin  ...  Mourtada Fall      4-3-3    Pranjal Banerjee
# 11           Odisha  ...    Rahul Bheke    4-2-3-1     Rowan Arumughan
# 12  Kerala Blasters  ...    Rahul Bheke    4-2-3-1    C. R. Srikrishna
# 13      Mohun Bagan  ...    Rahul Bheke    4-2-3-1     Tejas Nagvenkar
# 14    NorthEast Utd  ...  Mourtada Fall      4-3-3     Ashwin Mohanlal
# 15       Jamshedpur  ...  Mourtada Fall      4-3-3   S. Senthil Nathan
# 16     Hyderabad FC  ...  Mourtada Fall      4-3-3        Harish Kundu
# 17              Goa  ...   Ahmed Jahouh      4-3-3    Pranjal Banerjee
# 18        Bengaluru  ...  Mourtada Fall      4-3-3     Rowan Arumughan
#
#     Match Report Notes  Sh  SoT  Dist  PK  PKatt
# 0   Match Report   NaN  15    5   NaN   0      0
# 1   Match Report   NaN   7    3   NaN   0      0
# 2   Match Report   NaN  14    5   NaN   0      0
# 3   Match Report   NaN  16    4   NaN   0      0
# 4   Match Report   NaN  21    7   NaN   0      0
# 5   Match Report   NaN  18   11   NaN   1      1
# 6   Match Report   NaN  12    5   NaN   0      0
# 7   Match Report   NaN  22   13   NaN   1      1
# 8   Match Report   NaN  13    8   NaN   0      0
# 9   Match Report   NaN  19    9   NaN   0      1
# 10  Match Report   NaN  18    8   NaN   0      0
# 11  Match Report   NaN  16    9   NaN   0      0
# 12  Match Report   NaN   9    6   NaN   0      0
# 13  Match Report   NaN  13    9   NaN   0      0
# 14  Match Report   NaN  21   11   NaN   0      1
# 15  Match Report   NaN  14    4   NaN   0      0
# 16  Match Report   NaN  14    4   NaN   1      1
# 17  Match Report   NaN  15    8   NaN   1      1
# 18  Match Report   NaN  12    6   NaN   0      0
#
# [19 rows x 22 columns]

# %%
years = list(range(2022, 2020, -1))
all_matches = []
standings_url = "https://fbref.com/en/comps/82/Indian-Super-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 22

# %%
match_df = pd.concat(all_matches)
match_df.columns = [c.lower() for c in match_df.columns]
match_df
# Out:
#           date   time          comp         round  day venue result   gf   ga  \
# 0   2022-10-09  19:30  Super League   Matchweek 1  Sun  Away      D  3.0  3.0
# 1   2022-10-15  19:30  Super League   Matchweek 2  Sat  Home      W  2.0  0.0
# 2   2022-10-22  17:30  Super League   Matchweek 3  Sat  Home      D  1.0  1.0
# 3   2022-10-28  19:30  Super League   Matchweek 4  Fri  Away      W  2.0  0.0
# 4   2022-11-06  19:30  Super League   Matchweek 5  Sun  Home      D  2.0  2.0
# ..         ...    ...           ...           ...  ...   ...    ...  ...  ...
# 15  2022-02-07  19:30  Super League  Matchweek 17  Mon  Home      L    1    2
# 16  2022-02-14  19:30  Super League  Matchweek 21  Mon  Away      L    0    1
# 17  2022-02-22  19:30  Super League  Matchweek 18  Tue  Away      L    0    1
# 18  2022-02-28  19:30  Super League  Matchweek 19  Mon  Home      D    1    1
# 19  2022-03-05  19:30  Super League  Matchweek 20  Sat  Home      L    0    1
#
#            opponent  ...             referee  match report notes  sh sot dist  \
# 0      Hyderabad FC  ...     Tejas Nagvenkar  Match Report   NaN  15   5  NaN
# 1            Odisha  ...    Pranjal Banerjee  Match Report   NaN   7   3  NaN
# 2        Jamshedpur  ...        R. Venkatesh  Match Report   NaN  14   5  NaN
# 3   Kerala Blasters  ...  Aditya Purkayastha  Match Report   NaN  16   4  NaN
# 4       Mohun Bagan  ...     Rowan Arumughan  Match Report   NaN  21   7  NaN
# ..              ...  ...                 ...           ...   ...  ..  ..  ...
# 15           Odisha  ...     Rowan Arumughan  Match Report   NaN  15   2  NaN
# 16  Kerala Blasters  ...  Aditya Purkayastha  Match Report   NaN   9   1  NaN
# 17      Mumbai City  ...     Ashwin Mohanlal  Match Report   NaN  13   5  NaN
# 18    NorthEast Utd  ...     Tejas Nagvenkar  Match Report   NaN  18   6  NaN
# 19        Bengaluru  ...   S. Senthil Nathan  Match Report   NaN  17   5  NaN
#
#    pk  pkatt  season         team
# 0   0      0    2022  Mumbai City
# 1   0      0    2022  Mumbai City
# 2   0      0    2022  Mumbai City
# 3   0      0    2022  Mumbai City
# 4   0      0    2022  Mumbai City
# .. ..    ...     ...          ...
# 15  0      0    2021  East Bengal
# 16  0      0    2021  East Bengal
# 17  0      0    2021  East Bengal
# 18  1      1    2021  East Bengal
# 19  0      0    2021  East Bengal
#
# [438 rows x 24 columns]

# %%
match_df.to_csv("matches.csv")

# %%
match_df.shape
# Out:
# (438, 24)
